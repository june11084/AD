# %%
import torch
from torch import nn
from torchviz import make_dot, make_dot_from_trace

# sample code
model = nn.Sequential()
model.add_module('W0', nn.Linear(8, 16))
model.add_module('tanh', nn.Tanh())
model.add_module('W1', nn.Linear(16, 1))
x = torch.randn(1,8)
make_dot(model(x), params=dict(model.named_parameters()))

# %%
# visualization
import vae_models
model = vae_models.conv_VAE(20)
x = torch.randn(1,1,28).cuda
make_dot(model(x), params=dict(model.named_parameters()))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-99c7f3f65892> in <module>()
#       3 model = vae_models.conv_VAE(20)
#       4 x = torch.randn(1,1,28)
# ----> 5 make_dot(model(x), params=dict(model.named_parameters()))
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /home/xingyu/projects/anomaly_detection/vae_models.py in forward(self, x)
#     140         mu, logvar = self.encode(x)
#     141         # print("mu, logvar", mu.size(), logvar.size())
# --> 142         z = self.reparametrize(mu, logvar)
#     143         # print("z", z.size())
#     144         decoded = self.decode(z)
#
# /home/xingyu/projects/anomaly_detection/vae_models.py in reparametrize(self, mu, logvar)
#     134             eps = torch.FloatTensor(std.size()).normal_()
#     135         eps = Variable(eps)
# --> 136         return eps.mul(std).add_(mu)
#     137
#     138     def forward(self, x):
#
# RuntimeError: expected type torch.cuda.FloatTensor but got torch.FloatTensor
